# %%
import json

with open("gene.json", "rb") as fd:
    gene_data = json.load(fd)

# %%
metakg_edges = [
    ("biolink:Gene", "biolink:participates_in", "biolink:BiologicalProcess"),
    ("biolink:Gene", "biolink:has_participant", "biolink:BiologicalProcess"),
    ("biolink:Gene", "biolink:participates_in", "biolink:Pathway"),
]

# %%
biolink_map = {
    "biolink:Gene": {
        "path": "",
        "identifier": "entrezgene",
        "id_prefix": "NCBIGene",
        "properties": {
            "symbol": "symbol",
            "name": "name"
        }
    },
    "biolink:BiologicalProcess": {
        "path": "go.BP",
        "identifier": "id",
        "properties": {
            "evidence": "evidence",
            "term": "term"
        }
    },
    "biolink:has_participant": {
        "reverse": True
    },
    "biolink:Pathway": {
        "path": "pathway.reactome",
        "identifier": "id",
        "properties": {
            "name": "name",
        }
    },
}

# %%
from jsonpath_ng import parse

def extract_record(_id, datum, attr_dict, record_type, prefix):
    id_val = f"{prefix}:{datum[_id]}" if len(prefix) > 0 else datum[_id]
    record = {"id": id_val, "type": record_type}
    for k, v in attr_dict.items():
        record[k] = datum.get(v)
    return record

def preprocess_data(biolink_label: str, response: dict):
    data_field_map = biolink_map[biolink_label]
    path = data_field_map.get("path", "")
    jsonpath_expr = parse(f"$.{path}") if path else parse("$")

    matches = jsonpath_expr.find(response)
    if len(matches) != 1:
        raise ValueError(f"Matches need to be exactly 1 but are {len(matches)}, please provide a specific path {path}")

    data = matches[0].value
    if isinstance(data, dict) or isinstance(data, list):
        return data, data_field_map
    else:
        raise TypeError(f"Unexpected data type in JSONPath Match {type(data)}")

def get_subject_object_data(biolink_label: str, response: dict):
    try:
        data, data_field_map = preprocess_data(biolink_label, response)
    except ValueError:
        return []
    _id, prefix = data_field_map.get("identifier"), data_field_map.get("id_prefix", "")
    if _id is None:
        raise ValueError(f"Expected 'identifier' field but found None")

    records = []
    if isinstance(data, dict):
        # single record
        records.append(extract_record(_id, data, data_field_map["properties"], biolink_label, prefix))
    elif isinstance(data, list):
        # multiple records
        for datum in data:
            records.append(extract_record(_id, datum, data_field_map["properties"], biolink_label, prefix))

    return records

# %%
import biothings_client
from tqdm import tqdm

client = biothings_client.get_client("gene")

# %%
import itertools

def generate_records(metakg_edges, biolink_map):
    for gene_data in tqdm(client.query(q="__all__", species="human", fields="all", entrezonly=True, fetch_all=True)):
        for mkg_edge in metakg_edges:
            subjects = get_subject_object_data(mkg_edge[0], gene_data)
        
            predicate = {"type": mkg_edge[1]}
            reverse_edges = False
            if biolink_map.get(mkg_edge[1]):
                reverse_edges = biolink_map.get(mkg_edge[1]).get("reverse", False)
        
            objects = get_subject_object_data(mkg_edge[2], gene_data)
        
            for s, o in itertools.product(subjects, objects):
                if reverse_edges is False:
                    record = { "subject": s, "predicate": predicate, "object": o }
                else:
                    record = { "subject": o, "predicate": predicate, "object": s }
                yield record

# %%
records = list(generate_records(metakg_edges, biolink_map))
# Out:
# 193279it [1:25:30, 84.80it/s]No more results to return.
# 193285it [1:25:44, 37.57it/s]

# %%
print(json.dumps(records, indent=2))

# %%
len(records)
# Out:
# 460174

# %%
import json

with open("transformed_outputs.json", "w+") as fd:
    fd.write(json.dumps(records))

# %%
import random

random.choices(records, k=1000)
# Out:
# [{'subject': {'id': 'GO:0043129',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'surfactant homeostasis'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:4153',
#    'type': 'biolink:Gene',
#    'symbol': 'MBL2',
#    'name': 'mannose binding lectin 2'}},
#  {'subject': {'id': 'NCBIGene:7942',
#    'type': 'biolink:Gene',
#    'symbol': 'TFEB',
#    'name': 'transcription factor EB'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0002250',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'adaptive immune response'}},
#  {'subject': {'id': 'NCBIGene:6003',
#    'type': 'biolink:Gene',
#    'symbol': 'RGS13',
#    'name': 'regulator of G protein signaling 13'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-388396',
#    'type': 'biolink:Pathway',
#    'name': 'GPCR downstream signalling'}},
#  {'subject': {'id': 'NCBIGene:7364',
#    'type': 'biolink:Gene',
#    'symbol': 'UGT2B7',
#    'name': 'UDP glucuronosyltransferase family 2 member B7'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-211859',
#    'type': 'biolink:Pathway',
#    'name': 'Biological oxidations'}},
#  {'subject': {'id': 'GO:0010467',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'gene expression'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:4041',
#    'type': 'biolink:Gene',
#    'symbol': 'LRP5',
#    'name': 'LDL receptor related protein 5'}},
#  {'subject': {'id': 'NCBIGene:2975',
#    'type': 'biolink:Gene',
#    'symbol': 'GTF3C1',
#    'name': 'general transcription factor IIIC subunit 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-76066',
#    'type': 'biolink:Pathway',
#    'name': 'RNA Polymerase III Transcription Initiation From Type 2 Promoter'}},
#  {'subject': {'id': 'GO:0007052',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'mitotic spindle organization'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:23332',
#    'type': 'biolink:Gene',
#    'symbol': 'CLASP1',
#    'name': 'cytoplasmic linker associated protein 1'}},
#  {'subject': {'id': 'NCBIGene:26271',
#    'type': 'biolink:Gene',
#    'symbol': 'FBXO5',
#    'name': 'F-box protein 5'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0010971',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'positive regulation of G2/M transition of mitotic cell cycle'}},
#  {'subject': {'id': 'NCBIGene:6513',
#    'type': 'biolink:Gene',
#    'symbol': 'SLC2A1',
#    'name': 'solute carrier family 2 member 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0150104',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'NAS',
#    'term': 'transport across blood-brain barrier'}},
#  {'subject': {'id': 'NCBIGene:11181',
#    'type': 'biolink:Gene',
#    'symbol': 'TREH',
#    'name': 'trehalase'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-8935690',
#    'type': 'biolink:Pathway',
#    'name': 'Digestion'}},
#  {'subject': {'id': 'GO:0002230',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'positive regulation of defense response to virus by host'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:10758',
#    'type': 'biolink:Gene',
#    'symbol': 'TRAF3IP2',
#    'name': 'TRAF3 interacting protein 2'}},
#  {'subject': {'id': 'NCBIGene:3683',
#    'type': 'biolink:Gene',
#    'symbol': 'ITGAL',
#    'name': 'integrin subunit alpha L'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-1474244',
#    'type': 'biolink:Pathway',
#    'name': 'Extracellular matrix organization'}},
#  {'subject': {'id': 'NCBIGene:5552',
#    'type': 'biolink:Gene',
#    'symbol': 'SRGN',
#    'name': 'serglycin'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0140507',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'granzyme-mediated programmed cell death signaling pathway'}},
#  {'subject': {'id': 'GO:0051726',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'regulation of cell cycle'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:4683',
#    'type': 'biolink:Gene',
#    'symbol': 'NBN',
#    'name': 'nibrin'}},
#  {'subject': {'id': 'NCBIGene:253725',
#    'type': 'biolink:Gene',
#    'symbol': 'WASHC2C',
#    'name': 'WASH complex subunit 2C'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:2000813',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'negative regulation of barbed-end actin filament capping'}},
#  {'subject': {'id': 'GO:0006066',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'NAS',
#    'term': 'alcohol metabolic process'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:124',
#    'type': 'biolink:Gene',
#    'symbol': 'ADH1A',
#    'name': 'alcohol dehydrogenase 1A (class I), alpha polypeptide'}},
#  {'subject': {'id': 'NCBIGene:28976',
#    'type': 'biolink:Gene',
#    'symbol': 'ACAD9',
#    'name': 'acyl-CoA dehydrogenase family member 9'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-1430728',
#    'type': 'biolink:Pathway',
#    'name': 'Metabolism'}},
#  {'subject': {'id': 'GO:0099525',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'presynaptic dense core vesicle exocytosis'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:440279',
#    'type': 'biolink:Gene',
#    'symbol': 'UNC13C',
#    'name': 'unc-13 homolog C'}},
#  {'subject': {'id': 'NCBIGene:10376',
#    'type': 'biolink:Gene',
#    'symbol': 'TUBA1B',
#    'name': 'tubulin alpha 1b'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-1640170',
#    'type': 'biolink:Pathway',
#    'name': 'Cell Cycle'}},
#  {'subject': {'id': 'GO:0050673',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'epithelial cell proliferation'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:51208',
#    'type': 'biolink:Gene',
#    'symbol': 'CLDN18',
#    'name': 'claudin 18'}},
#  {'subject': {'id': 'GO:0006006',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'glucose metabolic process'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:80201',
#    'type': 'biolink:Gene',
#    'symbol': 'HKDC1',
#    'name': 'hexokinase domain containing 1'}},
#  {'subject': {'id': 'GO:0006893',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'Golgi to plasma membrane transport'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:57020',
#    'type': 'biolink:Gene',
#    'symbol': 'VPS35L',
#    'name': 'VPS35 endosomal protein sorting factor like'}},
#  {'subject': {'id': 'NCBIGene:25',
#    'type': 'biolink:Gene',
#    'symbol': 'ABL1',
#    'name': 'ABL proto-oncogene 1, non-receptor tyrosine kinase'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0007204',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'positive regulation of cytosolic calcium ion concentration'}},
#  {'subject': {'id': 'NCBIGene:7140',
#    'type': 'biolink:Gene',
#    'symbol': 'TNNT3',
#    'name': 'troponin T3, fast skeletal type'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0003009',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'skeletal muscle contraction'}},
#  {'subject': {'id': 'NCBIGene:406921',
#    'type': 'biolink:Gene',
#    'symbol': 'MIR132',
#    'name': 'microRNA 132'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0032715',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'negative regulation of interleukin-6 production'}},
#  {'subject': {'id': 'GO:0002250',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'adaptive immune response'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:28574',
#    'type': 'biolink:Gene',
#    'symbol': 'TRBV13',
#    'name': 'T cell receptor beta variable 13'}},
#  {'subject': {'id': 'NCBIGene:4481',
#    'type': 'biolink:Gene',
#    'symbol': 'MSR1',
#    'name': 'macrophage scavenger receptor 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-2173782',
#    'type': 'biolink:Pathway',
#    'name': 'Binding and Uptake of Ligands by Scavenger Receptors'}},
#  {'subject': {'id': 'GO:0016567',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'protein ubiquitination'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:10293',
#    'type': 'biolink:Gene',
#    'symbol': 'TRAIP',
#    'name': 'TRAF interacting protein'}},
#  {'subject': {'id': 'NCBIGene:1650',
#    'type': 'biolink:Gene',
#    'symbol': 'DDOST',
#    'name': 'dolichyl-diphosphooligosaccharide--protein glycosyltransferase non-catalytic subunit'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-392499',
#    'type': 'biolink:Pathway',
#    'name': 'Metabolism of proteins'}},
#  {'subject': {'id': 'NCBIGene:28514',
#    'type': 'biolink:Gene',
#    'symbol': 'DLL1',
#    'name': 'delta like canonical Notch ligand 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0021688',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'cerebellar molecular layer formation'}},
#  {'subject': {'id': 'GO:0045920',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'negative regulation of exocytosis'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:29091',
#    'type': 'biolink:Gene',
#    'symbol': 'STXBP6',
#    'name': 'syntaxin binding protein 6'}},
#  {'subject': {'id': 'NCBIGene:5595',
#    'type': 'biolink:Gene',
#    'symbol': 'MAPK3',
#    'name': 'mitogen-activated protein kinase 3'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-5675221',
#    'type': 'biolink:Pathway',
#    'name': 'Negative regulation of MAPK pathway'}},
#  {'subject': {'id': 'NCBIGene:28999',
#    'type': 'biolink:Gene',
#    'symbol': 'KLF15',
#    'name': 'KLF transcription factor 15'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:2000757',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'negative regulation of peptidyl-lysine acetylation'}},
#  {'subject': {'id': 'GO:0051607',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'defense response to virus'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:10417',
#    'type': 'biolink:Gene',
#    'symbol': 'SPON2',
#    'name': 'spondin 2'}},
#  {'subject': {'id': 'NCBIGene:2853',
#    'type': 'biolink:Gene',
#    'symbol': 'GPR31',
#    'name': 'G protein-coupled receptor 31'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-388396',
#    'type': 'biolink:Pathway',
#    'name': 'GPCR downstream signalling'}},
#  {'subject': {'id': 'NCBIGene:51321',
#    'type': 'biolink:Gene',
#    'symbol': 'AMZ2',
#    'name': 'archaelysin family metallopeptidase 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0006508',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'proteolysis'}},
#  {'subject': {'id': 'GO:0007159',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEP',
#    'term': 'leukocyte cell-cell adhesion'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:4478',
#    'type': 'biolink:Gene',
#    'symbol': 'MSN',
#    'name': 'moesin'}},
#  {'subject': {'id': 'NCBIGene:2562',
#    'type': 'biolink:Gene',
#    'symbol': 'GABRB3',
#    'name': 'gamma-aminobutyric acid type A receptor subunit beta3'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:1902476',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'chloride transmembrane transport'}},
#  {'subject': {'id': 'GO:0000122',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'negative regulation of transcription by RNA polymerase II'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:56676',
#    'type': 'biolink:Gene',
#    'symbol': 'ASCL3',
#    'name': 'achaete-scute family bHLH transcription factor 3'}},
#  {'subject': {'id': 'GO:0008284',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'positive regulation of cell population proliferation'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:7472',
#    'type': 'biolink:Gene',
#    'symbol': 'WNT2',
#    'name': 'Wnt family member 2'}},
#  {'subject': {'id': 'NCBIGene:25794',
#    'type': 'biolink:Gene',
#    'symbol': 'FSCN2',
#    'name': 'fascin actin-bundling protein 2, retinal'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0007601',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'visual perception'}},
#  {'subject': {'id': 'NCBIGene:2335',
#    'type': 'biolink:Gene',
#    'symbol': 'FN1',
#    'name': 'fibronectin 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-9656223',
#    'type': 'biolink:Pathway',
#    'name': 'Signaling by RAF1 mutants'}},
#  {'subject': {'id': 'NCBIGene:10125',
#    'type': 'biolink:Gene',
#    'symbol': 'RASGRP1',
#    'name': 'RAS guanyl releasing protein 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0051896',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'regulation of phosphatidylinositol 3-kinase/protein kinase B signal transduction'}},
#  {'subject': {'id': 'GO:1904754',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'positive regulation of vascular associated smooth muscle cell migration'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:406991',
#    'type': 'biolink:Gene',
#    'symbol': 'MIR21',
#    'name': 'microRNA 21'}},
#  {'subject': {'id': 'GO:0034113',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IGI',
#    'term': 'heterotypic cell-cell adhesion'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:3676',
#    'type': 'biolink:Gene',
#    'symbol': 'ITGA4',
#    'name': 'integrin subunit alpha 4'}},
#  {'subject': {'id': 'NCBIGene:51003',
#    'type': 'biolink:Gene',
#    'symbol': 'MED31',
#    'name': 'mediator complex subunit 31'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-212165',
#    'type': 'biolink:Pathway',
#    'name': 'Epigenetic regulation of gene expression'}},
#  {'subject': {'id': 'GO:0006355',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'regulation of DNA-templated transcription'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:162655',
#    'type': 'biolink:Gene',
#    'symbol': 'ZNF519',
#    'name': 'zinc finger protein 519'}},
#  {'subject': {'id': 'NCBIGene:25769',
#    'type': 'biolink:Gene',
#    'symbol': 'SLC24A2',
#    'name': 'solute carrier family 24 member 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0006874',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'intracellular calcium ion homeostasis'}},
#  {'subject': {'id': 'GO:0030111',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'regulation of Wnt signaling pathway'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:51527',
#    'type': 'biolink:Gene',
#    'symbol': 'GSKIP',
#    'name': 'GSK3B interacting protein'}},
#  {'subject': {'id': 'NCBIGene:7071',
#    'type': 'biolink:Gene',
#    'symbol': 'KLF10',
#    'name': 'KLF transcription factor 10'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0045892',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'negative regulation of DNA-templated transcription'}},
#  {'subject': {'id': 'GO:0030514',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'negative regulation of BMP signaling pathway'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:406978',
#    'type': 'biolink:Gene',
#    'symbol': 'MIR199B',
#    'name': 'microRNA 199b'}},
#  {'subject': {'id': 'NCBIGene:57534',
#    'type': 'biolink:Gene',
#    'symbol': 'MIB1',
#    'name': 'MIB E3 ubiquitin protein ligase 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0045665',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'negative regulation of neuron differentiation'}},
#  {'subject': {'id': 'GO:0002053',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'positive regulation of mesenchymal cell proliferation'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:6474',
#    'type': 'biolink:Gene',
#    'symbol': 'SHOX2',
#    'name': 'SHOX homeobox 2'}},
#  {'subject': {'id': 'NCBIGene:80823',
#    'type': 'biolink:Gene',
#    'symbol': 'GPRASP3',
#    'name': 'G protein-coupled receptor associated sorting protein family member 3'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0051965',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'positive regulation of synapse assembly'}},
#  {'subject': {'id': 'GO:0110076',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'negative regulation of ferroptosis'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:2879',
#    'type': 'biolink:Gene',
#    'symbol': 'GPX4',
#    'name': 'glutathione peroxidase 4'}},
#  {'subject': {'id': 'NCBIGene:6850',
#    'type': 'biolink:Gene',
#    'symbol': 'SYK',
#    'name': 'spleen associated tyrosine kinase'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0035556',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'intracellular signal transduction'}},
#  {'subject': {'id': 'NCBIGene:56751',
#    'type': 'biolink:Gene',
#    'symbol': 'BARHL1',
#    'name': 'BarH like homeobox 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:1905584',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'outer hair cell apoptotic process'}},
#  {'subject': {'id': 'NCBIGene:2125',
#    'type': 'biolink:Gene',
#    'symbol': 'EVPL',
#    'name': 'envoplakin'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0045104',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'intermediate filament cytoskeleton organization'}},
#  {'subject': {'id': 'NCBIGene:6434',
#    'type': 'biolink:Gene',
#    'symbol': 'TRA2B',
#    'name': 'transformer 2 beta homolog'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-9012999',
#    'type': 'biolink:Pathway',
#    'name': 'RHO GTPase cycle'}},
#  {'subject': {'id': 'NCBIGene:64983',
#    'type': 'biolink:Gene',
#    'symbol': 'MRPL32',
#    'name': 'mitochondrial ribosomal protein L32'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-392499',
#    'type': 'biolink:Pathway',
#    'name': 'Metabolism of proteins'}},
#  {'subject': {'id': 'NCBIGene:55236',
#    'type': 'biolink:Gene',
#    'symbol': 'UBA6',
#    'name': 'ubiquitin like modifier activating enzyme 6'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-597592',
#    'type': 'biolink:Pathway',
#    'name': 'Post-translational protein modification'}},
#  {'subject': {'id': 'GO:0017190',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'N-terminal peptidyl-aspartic acid acetylation'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:51126',
#    'type': 'biolink:Gene',
#    'symbol': 'NAA20',
#    'name': 'N-alpha-acetyltransferase 20, NatB catalytic subunit'}},
#  {'subject': {'id': 'GO:0072015',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'podocyte development'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:5420',
#    'type': 'biolink:Gene',
#    'symbol': 'PODXL',
#    'name': 'podocalyxin like'}},
#  {'subject': {'id': 'NCBIGene:808',
#    'type': 'biolink:Gene',
#    'symbol': 'CALM3',
#    'name': 'calmodulin 3'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-397014',
#    'type': 'biolink:Pathway',
#    'name': 'Muscle contraction'}},
#  {'subject': {'id': 'NCBIGene:4717',
#    'type': 'biolink:Gene',
#    'symbol': 'NDUFC1',
#    'name': 'NADH:ubiquinone oxidoreductase subunit C1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-6799198',
#    'type': 'biolink:Pathway',
#    'name': 'Complex I biogenesis'}},
#  {'subject': {'id': 'GO:0030324',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'lung development'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:3290',
#    'type': 'biolink:Gene',
#    'symbol': 'HSD11B1',
#    'name': 'hydroxysteroid 11-beta dehydrogenase 1'}},
#  {'subject': {'id': 'GO:0006355',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'regulation of DNA-templated transcription'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:401898',
#    'type': 'biolink:Gene',
#    'symbol': 'ZNF833P',
#    'name': 'zinc finger protein 833, pseudogene'}},
#  {'subject': {'id': 'NCBIGene:347733',
#    'type': 'biolink:Gene',
#    'symbol': 'TUBB2B',
#    'name': 'tubulin beta 2B class IIb'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-199991',
#    'type': 'biolink:Pathway',
#    'name': 'Membrane Trafficking'}},
#  {'subject': {'id': 'NCBIGene:6474',
#    'type': 'biolink:Gene',
#    'symbol': 'SHOX2',
#    'name': 'SHOX homeobox 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0060931',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'sinoatrial node cell development'}},
#  {'subject': {'id': 'NCBIGene:4128',
#    'type': 'biolink:Gene',
#    'symbol': 'MAOA',
#    'name': 'monoamine oxidase A'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-140179',
#    'type': 'biolink:Pathway',
#    'name': 'Amine Oxidase reactions'}},
#  {'subject': {'id': 'GO:0036499',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'PERK-mediated unfolded protein response'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:468',
#    'type': 'biolink:Gene',
#    'symbol': 'ATF4',
#    'name': 'activating transcription factor 4'}},
#  {'subject': {'id': 'GO:0007098',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'centrosome cycle'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:80817',
#    'type': 'biolink:Gene',
#    'symbol': 'CEP44',
#    'name': 'centrosomal protein 44'}},
#  {'subject': {'id': 'GO:0009624',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'response to nematode'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:64806',
#    'type': 'biolink:Gene',
#    'symbol': 'IL25',
#    'name': 'interleukin 25'}},
#  {'subject': {'id': 'NCBIGene:5731',
#    'type': 'biolink:Gene',
#    'symbol': 'PTGER1',
#    'name': 'prostaglandin E receptor 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-373076',
#    'type': 'biolink:Pathway',
#    'name': 'Class A/1 (Rhodopsin-like receptors)'}},
#  {'subject': {'id': 'NCBIGene:291',
#    'type': 'biolink:Gene',
#    'symbol': 'SLC25A4',
#    'name': 'solute carrier family 25 member 4'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0015853',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'adenine transport'}},
#  {'subject': {'id': 'GO:0046605',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'regulation of centrosome cycle'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:22809',
#    'type': 'biolink:Gene',
#    'symbol': 'ATF5',
#    'name': 'activating transcription factor 5'}},
#  {'subject': {'id': 'NCBIGene:4267',
#    'type': 'biolink:Gene',
#    'symbol': 'CD99',
#    'name': 'CD99 molecule (Xg blood group)'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-109582',
#    'type': 'biolink:Pathway',
#    'name': 'Hemostasis'}},
#  {'subject': {'id': 'GO:0060070',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'canonical Wnt signaling pathway'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:283149',
#    'type': 'biolink:Gene',
#    'symbol': 'BCL9L',
#    'name': 'BCL9 like'}},
#  {'subject': {'id': 'NCBIGene:6152',
#    'type': 'biolink:Gene',
#    'symbol': 'RPL24',
#    'name': 'ribosomal protein L24'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-192823',
#    'type': 'biolink:Pathway',
#    'name': 'Viral mRNA Translation'}},
#  {'subject': {'id': 'NCBIGene:368',
#    'type': 'biolink:Gene',
#    'symbol': 'ABCC6',
#    'name': 'ATP binding cassette subfamily C member 6'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:1904383',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'response to sodium phosphate'}},
#  {'subject': {'id': 'NCBIGene:10152',
#    'type': 'biolink:Gene',
#    'symbol': 'ABI2',
#    'name': 'abl interactor 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0016477',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'cell migration'}},
#  {'subject': {'id': 'NCBIGene:1577',
#    'type': 'biolink:Gene',
#    'symbol': 'CYP3A5',
#    'name': 'cytochrome P450 family 3 subfamily A member 5'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0006805',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'xenobiotic metabolic process'}},
#  {'subject': {'id': 'NCBIGene:83756',
#    'type': 'biolink:Gene',
#    'symbol': 'TAS1R3',
#    'name': 'taste 1 receptor member 3'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0050917',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'sensory perception of umami taste'}},
#  {'subject': {'id': 'NCBIGene:1977',
#    'type': 'biolink:Gene',
#    'symbol': 'EIF4E',
#    'name': 'eukaryotic translation initiation factor 4E'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0006413',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'translational initiation'}},
#  {'subject': {'id': 'NCBIGene:10178',
#    'type': 'biolink:Gene',
#    'symbol': 'TENM1',
#    'name': 'teneurin transmembrane protein 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0048666',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'neuron development'}},
#  {'subject': {'id': 'NCBIGene:27161',
#    'type': 'biolink:Gene',
#    'symbol': 'AGO2',
#    'name': 'argonaute RISC catalytic component 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0045727',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'positive regulation of translation'}},
#  {'subject': {'id': 'NCBIGene:8604',
#    'type': 'biolink:Gene',
#    'symbol': 'SLC25A12',
#    'name': 'solute carrier family 25 member 12'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-9609507',
#    'type': 'biolink:Pathway',
#    'name': 'Protein localization'}},
#  {'subject': {'id': 'NCBIGene:819',
#    'type': 'biolink:Gene',
#    'symbol': 'CAMLG',
#    'name': 'calcium modulating ligand'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0050821',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'protein stabilization'}},
#  {'subject': {'id': 'NCBIGene:9968',
#    'type': 'biolink:Gene',
#    'symbol': 'MED12',
#    'name': 'mediator complex subunit 12'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0045893',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'positive regulation of DNA-templated transcription'}},
#  {'subject': {'id': 'GO:0016925',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'protein sumoylation'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:8554',
#    'type': 'biolink:Gene',
#    'symbol': 'PIAS1',
#    'name': 'protein inhibitor of activated STAT 1'}},
#  {'subject': {'id': 'NCBIGene:10048',
#    'type': 'biolink:Gene',
#    'symbol': 'RANBP9',
#    'name': 'RAN binding protein 9'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-1266738',
#    'type': 'biolink:Pathway',
#    'name': 'Developmental Biology'}},
#  {'subject': {'id': 'NCBIGene:2773',
#    'type': 'biolink:Gene',
#    'symbol': 'GNAI3',
#    'name': 'G protein subunit alpha i3'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-112316',
#    'type': 'biolink:Pathway',
#    'name': 'Neuronal System'}},
#  {'subject': {'id': 'NCBIGene:286826',
#    'type': 'biolink:Gene',
#    'symbol': 'LIN9',
#    'name': 'lin-9 DREAM MuvB core complex component'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-69656',
#    'type': 'biolink:Pathway',
#    'name': 'Cyclin A:Cdk2-associated events at S phase entry'}},
#  {'subject': {'id': 'NCBIGene:55706',
#    'type': 'biolink:Gene',
#    'symbol': 'NDC1',
#    'name': 'NDC1 transmembrane nucleoporin'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-2990846',
#    'type': 'biolink:Pathway',
#    'name': 'SUMOylation'}},
#  {'subject': {'id': 'NCBIGene:107161145',
#    'type': 'biolink:Gene',
#    'symbol': 'PMS2P11',
#    'name': 'PMS1 homolog 2, mismatch repair system component pseudogene 11'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0016310',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'phosphorylation'}},
#  {'subject': {'id': 'NCBIGene:115557',
#    'type': 'biolink:Gene',
#    'symbol': 'ARHGEF25',
#    'name': 'Rho guanine nucleotide exchange factor 25'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-162582',
#    'type': 'biolink:Pathway',
#    'name': 'Signal Transduction'}},
#  {'subject': {'id': 'GO:0098535',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'de novo centriole assembly involved in multi-ciliated epithelial cell differentiation'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:159989',
#    'type': 'biolink:Gene',
#    'symbol': 'DEUP1',
#    'name': 'deuterosome assembly protein 1'}},
#  {'subject': {'id': 'NCBIGene:1387',
#    'type': 'biolink:Gene',
#    'symbol': 'CREBBP',
#    'name': 'CREB binding protein'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-162582',
#    'type': 'biolink:Pathway',
#    'name': 'Signal Transduction'}},
#  {'subject': {'id': 'NCBIGene:8338',
#    'type': 'biolink:Gene',
#    'symbol': 'H2AC20',
#    'name': 'H2A clustered histone 20'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-427413',
#    'type': 'biolink:Pathway',
#    'name': 'NoRC negatively regulates rRNA expression'}},
#  {'subject': {'id': 'NCBIGene:7335',
#    'type': 'biolink:Gene',
#    'symbol': 'UBE2V1',
#    'name': 'ubiquitin conjugating enzyme E2 V1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-2454202',
#    'type': 'biolink:Pathway',
#    'name': 'Fc epsilon receptor (FCERI) signaling'}},
#  {'subject': {'id': 'NCBIGene:58500',
#    'type': 'biolink:Gene',
#    'symbol': 'ZNF250',
#    'name': 'zinc finger protein 250'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-212436',
#    'type': 'biolink:Pathway',
#    'name': 'Generic Transcription Pathway'}},
#  {'subject': {'id': 'GO:0006366',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'transcription by RNA polymerase II'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:51755',
#    'type': 'biolink:Gene',
#    'symbol': 'CDK12',
#    'name': 'cyclin dependent kinase 12'}},
#  {'subject': {'id': 'NCBIGene:325',
#    'type': 'biolink:Gene',
#    'symbol': 'APCS',
#    'name': 'amyloid P component, serum'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0051131',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'chaperone-mediated protein complex assembly'}},
#  {'subject': {'id': 'NCBIGene:10392',
#    'type': 'biolink:Gene',
#    'symbol': 'NOD1',
#    'name': 'nucleotide binding oligomerization domain containing 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0002221',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'pattern recognition receptor signaling pathway'}},
#  {'subject': {'id': 'GO:0042149',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'cellular response to glucose starvation'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:26608',
#    'type': 'biolink:Gene',
#    'symbol': 'TBL2',
#    'name': 'transducin beta like 2'}},
#  {'subject': {'id': 'NCBIGene:128312',
#    'type': 'biolink:Gene',
#    'symbol': 'H2BC26',
#    'name': 'H2B clustered histone 26'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-73928',
#    'type': 'biolink:Pathway',
#    'name': 'Depyrimidination'}},
#  {'subject': {'id': 'GO:0021904',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'dorsal/ventral neural tube patterning'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:89780',
#    'type': 'biolink:Gene',
#    'symbol': 'WNT3A',
#    'name': 'Wnt family member 3A'}},
#  {'subject': {'id': 'NCBIGene:7442',
#    'type': 'biolink:Gene',
#    'symbol': 'TRPV1',
#    'name': 'transient receptor potential cation channel subfamily V member 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0007635',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'chemosensory behavior'}},
#  {'subject': {'id': 'GO:0097535',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'lymphoid lineage cell migration into thymus'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:64919',
#    'type': 'biolink:Gene',
#    'symbol': 'BCL11B',
#    'name': 'BCL11 transcription factor B'}},
#  {'subject': {'id': 'GO:0006509',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'membrane protein ectodomain proteolysis'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:5664',
#    'type': 'biolink:Gene',
#    'symbol': 'PSEN2',
#    'name': 'presenilin 2'}},
#  {'subject': {'id': 'NCBIGene:5617',
#    'type': 'biolink:Gene',
#    'symbol': 'PRL',
#    'name': 'prolactin'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0016525',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'NAS',
#    'term': 'negative regulation of angiogenesis'}},
#  {'subject': {'id': 'NCBIGene:5788',
#    'type': 'biolink:Gene',
#    'symbol': 'PTPRC',
#    'name': 'protein tyrosine phosphatase receptor type C'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0002639',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'positive regulation of immunoglobulin production'}},
#  {'subject': {'id': 'NCBIGene:92667',
#    'type': 'biolink:Gene',
#    'symbol': 'MGME1',
#    'name': 'mitochondrial genome maintenance exonuclease 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0006264',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'mitochondrial DNA replication'}},
#  {'subject': {'id': 'NCBIGene:8602',
#    'type': 'biolink:Gene',
#    'symbol': 'NOP14',
#    'name': 'NOP14 nucleolar protein'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-8868773',
#    'type': 'biolink:Pathway',
#    'name': 'rRNA processing in the nucleus and cytosol'}},
#  {'subject': {'id': 'NCBIGene:5317',
#    'type': 'biolink:Gene',
#    'symbol': 'PKP1',
#    'name': 'plakophilin 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-168249',
#    'type': 'biolink:Pathway',
#    'name': 'Innate Immune System'}},
#  {'subject': {'id': 'GO:0030036',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'actin cytoskeleton organization'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:25',
#    'type': 'biolink:Gene',
#    'symbol': 'ABL1',
#    'name': 'ABL proto-oncogene 1, non-receptor tyrosine kinase'}},
#  {'subject': {'id': 'GO:0007268',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'chemical synaptic transmission'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:2915',
#    'type': 'biolink:Gene',
#    'symbol': 'GRM5',
#    'name': 'glutamate metabotropic receptor 5'}},
#  {'subject': {'id': 'NCBIGene:55870',
#    'type': 'biolink:Gene',
#    'symbol': 'ASH1L',
#    'name': 'ASH1 like histone lysine methyltransferase'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0001501',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'skeletal system development'}},
#  {'subject': {'id': 'NCBIGene:1954',
#    'type': 'biolink:Gene',
#    'symbol': 'MEGF8',
#    'name': 'multiple EGF like domains 8'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0030326',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'embryonic limb morphogenesis'}},
#  {'subject': {'id': 'NCBIGene:84085',
#    'type': 'biolink:Gene',
#    'symbol': 'FBXO30',
#    'name': 'F-box protein 30'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-168256',
#    'type': 'biolink:Pathway',
#    'name': 'Immune System'}},
#  {'subject': {'id': 'GO:0006979',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'NAS',
#    'term': 'response to oxidative stress'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:7001',
#    'type': 'biolink:Gene',
#    'symbol': 'PRDX2',
#    'name': 'peroxiredoxin 2'}},
#  {'subject': {'id': 'GO:0043010',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'camera-type eye development'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:30062',
#    'type': 'biolink:Gene',
#    'symbol': 'RAX',
#    'name': 'retina and anterior neural fold homeobox'}},
#  {'subject': {'id': 'GO:0007165',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'signal transduction'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:8792',
#    'type': 'biolink:Gene',
#    'symbol': 'TNFRSF11A',
#    'name': 'TNF receptor superfamily member 11a'}},
#  {'subject': {'id': 'GO:0071243',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'cellular response to arsenic-containing substance'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:2872',
#    'type': 'biolink:Gene',
#    'symbol': 'MKNK2',
#    'name': 'MAPK interacting serine/threonine kinase 2'}},
#  {'subject': {'id': 'NCBIGene:3779',
#    'type': 'biolink:Gene',
#    'symbol': 'KCNMB1',
#    'name': 'potassium calcium-activated channel subfamily M regulatory beta subunit 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-9659379',
#    'type': 'biolink:Pathway',
#    'name': 'Sensory processing of sound'}},
#  {'subject': {'id': 'NCBIGene:3949',
#    'type': 'biolink:Gene',
#    'symbol': 'LDLR',
#    'name': 'low density lipoprotein receptor'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-2187338',
#    'type': 'biolink:Pathway',
#    'name': 'Visual phototransduction'}},
#  {'subject': {'id': 'NCBIGene:10267',
#    'type': 'biolink:Gene',
#    'symbol': 'RAMP1',
#    'name': 'receptor activity modifying protein 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-373080',
#    'type': 'biolink:Pathway',
#    'name': 'Class B/2 (Secretin family receptors)'}},
#  {'subject': {'id': 'NCBIGene:4686',
#    'type': 'biolink:Gene',
#    'symbol': 'NCBP1',
#    'name': 'nuclear cap binding protein subunit 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-1643685',
#    'type': 'biolink:Pathway',
#    'name': 'Disease'}},
#  {'subject': {'id': 'NCBIGene:3845',
#    'type': 'biolink:Gene',
#    'symbol': 'KRAS',
#    'name': 'KRAS proto-oncogene, GTPase'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-112412',
#    'type': 'biolink:Pathway',
#    'name': 'SOS-mediated signalling'}},
#  {'subject': {'id': 'NCBIGene:10410',
#    'type': 'biolink:Gene',
#    'symbol': 'IFITM3',
#    'name': 'interferon induced transmembrane protein 3'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-168256',
#    'type': 'biolink:Pathway',
#    'name': 'Immune System'}},
#  {'subject': {'id': 'NCBIGene:11254',
#    'type': 'biolink:Gene',
#    'symbol': 'SLC6A14',
#    'name': 'solute carrier family 6 member 14'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-5619102',
#    'type': 'biolink:Pathway',
#    'name': 'SLC transporter disorders'}},
#  {'subject': {'id': 'NCBIGene:121504',
#    'type': 'biolink:Gene',
#    'symbol': 'H4C16',
#    'name': 'H4 histone 16'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-2559580',
#    'type': 'biolink:Pathway',
#    'name': 'Oxidative Stress Induced Senescence'}},
#  {'subject': {'id': 'GO:0007369',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'gastrulation'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:10139',
#    'type': 'biolink:Gene',
#    'symbol': 'ARFRP1',
#    'name': 'ARF related protein 1'}},
#  {'subject': {'id': 'GO:0050821',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'protein stabilization'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:7466',
#    'type': 'biolink:Gene',
#    'symbol': 'WFS1',
#    'name': 'wolframin ER transmembrane glycoprotein'}},
#  {'subject': {'id': 'GO:0007155',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'cell adhesion'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:50856',
#    'type': 'biolink:Gene',
#    'symbol': 'CLEC4A',
#    'name': 'C-type lectin domain family 4 member A'}},
#  {'subject': {'id': 'NCBIGene:3263',
#    'type': 'biolink:Gene',
#    'symbol': 'HPX',
#    'name': 'hemopexin'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-5653656',
#    'type': 'biolink:Pathway',
#    'name': 'Vesicle-mediated transport'}},
#  {'subject': {'id': 'NCBIGene:841',
#    'type': 'biolink:Gene',
#    'symbol': 'CASP8',
#    'name': 'caspase 8'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-5357769',
#    'type': 'biolink:Pathway',
#    'name': 'Caspase activation via extrinsic apoptotic signalling pathway'}},
#  {'subject': {'id': 'NCBIGene:8243',
#    'type': 'biolink:Gene',
#    'symbol': 'SMC1A',
#    'name': 'structural maintenance of chromosomes 1A'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-1221632',
#    'type': 'biolink:Pathway',
#    'name': 'Meiotic synapsis'}},
#  {'subject': {'id': 'NCBIGene:3364',
#    'type': 'biolink:Gene',
#    'symbol': 'HUS1',
#    'name': 'HUS1 checkpoint clamp component'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-176187',
#    'type': 'biolink:Pathway',
#    'name': 'Activation of ATR in response to replication stress'}},
#  {'subject': {'id': 'NCBIGene:8743',
#    'type': 'biolink:Gene',
#    'symbol': 'TNFSF10',
#    'name': 'TNF superfamily member 10'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0036462',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'TRAIL-activated apoptotic signaling pathway'}},
#  {'subject': {'id': 'NCBIGene:88',
#    'type': 'biolink:Gene',
#    'symbol': 'ACTN2',
#    'name': 'actinin alpha 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-442742',
#    'type': 'biolink:Pathway',
#    'name': 'CREB1 phosphorylation through NMDA receptor-mediated activation of RAS signaling'}},
#  {'subject': {'id': 'NCBIGene:55718',
#    'type': 'biolink:Gene',
#    'symbol': 'POLR3E',
#    'name': 'RNA polymerase III subunit E'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-74160',
#    'type': 'biolink:Pathway',
#    'name': 'Gene expression (Transcription)'}},
#  {'subject': {'id': 'GO:0045109',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'intermediate filament organization'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:2670',
#    'type': 'biolink:Gene',
#    'symbol': 'GFAP',
#    'name': 'glial fibrillary acidic protein'}},
#  {'subject': {'id': 'GO:0010634',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IGI',
#    'term': 'positive regulation of epithelial cell migration'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:7429',
#    'type': 'biolink:Gene',
#    'symbol': 'VIL1',
#    'name': 'villin 1'}},
#  {'subject': {'id': 'GO:0051216',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'cartilage development'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:4086',
#    'type': 'biolink:Gene',
#    'symbol': 'SMAD1',
#    'name': 'SMAD family member 1'}},
#  {'subject': {'id': 'NCBIGene:6137',
#    'type': 'biolink:Gene',
#    'symbol': 'RPL13',
#    'name': 'ribosomal protein L13'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-392499',
#    'type': 'biolink:Pathway',
#    'name': 'Metabolism of proteins'}},
#  {'subject': {'id': 'GO:0045893',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'positive regulation of DNA-templated transcription'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:7043',
#    'type': 'biolink:Gene',
#    'symbol': 'TGFB3',
#    'name': 'transforming growth factor beta 3'}},
#  {'subject': {'id': 'NCBIGene:9037',
#    'type': 'biolink:Gene',
#    'symbol': 'SEMA5A',
#    'name': 'semaphorin 5A'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-597592',
#    'type': 'biolink:Pathway',
#    'name': 'Post-translational protein modification'}},
#  {'subject': {'id': 'NCBIGene:26281',
#    'type': 'biolink:Gene',
#    'symbol': 'FGF20',
#    'name': 'fibroblast growth factor 20'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-5684996',
#    'type': 'biolink:Pathway',
#    'name': 'MAPK1/MAPK3 signaling'}},
#  {'subject': {'id': 'NCBIGene:4089',
#    'type': 'biolink:Gene',
#    'symbol': 'SMAD4',
#    'name': 'SMAD family member 4'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-8878166',
#    'type': 'biolink:Pathway',
#    'name': 'Transcriptional regulation by RUNX2'}},
#  {'subject': {'id': 'NCBIGene:1778',
#    'type': 'biolink:Gene',
#    'symbol': 'DYNC1H1',
#    'name': 'dynein cytoplasmic 1 heavy chain 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-8953897',
#    'type': 'biolink:Pathway',
#    'name': 'Cellular responses to stimuli'}},
#  {'subject': {'id': 'NCBIGene:4291',
#    'type': 'biolink:Gene',
#    'symbol': 'MLF1',
#    'name': 'myeloid leukemia factor 1'},
# ...
#   'object': {'id': 'NCBIGene:5578',
#    'type': 'biolink:Gene',
#    'symbol': 'PRKCA',
#    'name': 'protein kinase C alpha'}},
#  {'subject': {'id': 'NCBIGene:6657',
#    'type': 'biolink:Gene',
#    'symbol': 'SOX2',
#    'name': 'SRY-box transcription factor 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-212436',
#    'type': 'biolink:Pathway',
#    'name': 'Generic Transcription Pathway'}},
#  {'subject': {'id': 'GO:0045786',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'negative regulation of cell cycle'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:26001',
#    'type': 'biolink:Gene',
#    'symbol': 'RNF167',
#    'name': 'ring finger protein 167'}},
#  {'subject': {'id': 'NCBIGene:53905',
#    'type': 'biolink:Gene',
#    'symbol': 'DUOX1',
#    'name': 'dual oxidase 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0042554',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'NAS',
#    'term': 'superoxide anion generation'}},
#  {'subject': {'id': 'GO:0045893',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'positive regulation of DNA-templated transcription'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:90',
#    'type': 'biolink:Gene',
#    'symbol': 'ACVR1',
#    'name': 'activin A receptor type 1'}},
#  {'subject': {'id': 'NCBIGene:8239',
#    'type': 'biolink:Gene',
#    'symbol': 'USP9X',
#    'name': 'ubiquitin specific peptidase 9 X-linked'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-9609507',
#    'type': 'biolink:Pathway',
#    'name': 'Protein localization'}},
#  {'subject': {'id': 'GO:0033147',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'negative regulation of intracellular estrogen receptor signaling pathway'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:3670',
#    'type': 'biolink:Gene',
#    'symbol': 'ISL1',
#    'name': 'ISL LIM homeobox 1'}},
#  {'subject': {'id': 'NCBIGene:53371',
#    'type': 'biolink:Gene',
#    'symbol': 'NUP54',
#    'name': 'nucleoporin 54'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-597592',
#    'type': 'biolink:Pathway',
#    'name': 'Post-translational protein modification'}},
#  {'subject': {'id': 'GO:0019547',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'arginine catabolic process to ornithine'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:383',
#    'type': 'biolink:Gene',
#    'symbol': 'ARG1',
#    'name': 'arginase 1'}},
#  {'subject': {'id': 'NCBIGene:55114',
#    'type': 'biolink:Gene',
#    'symbol': 'ARHGAP17',
#    'name': 'Rho GTPase activating protein 17'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-9716542',
#    'type': 'biolink:Pathway',
#    'name': 'Signaling by Rho GTPases, Miro GTPases and RHOBTB3'}},
#  {'subject': {'id': 'GO:0042273',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'ribosomal large subunit biogenesis'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:90441',
#    'type': 'biolink:Gene',
#    'symbol': 'ZNF622',
#    'name': 'zinc finger protein 622'}},
#  {'subject': {'id': 'NCBIGene:11221',
#    'type': 'biolink:Gene',
#    'symbol': 'DUSP10',
#    'name': 'dual specificity phosphatase 10'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0043508',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'negative regulation of JUN kinase activity'}},
#  {'subject': {'id': 'NCBIGene:1022',
#    'type': 'biolink:Gene',
#    'symbol': 'CDK7',
#    'name': 'cyclin dependent kinase 7'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0006367',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'transcription initiation at RNA polymerase II promoter'}},
#  {'subject': {'id': 'NCBIGene:80168',
#    'type': 'biolink:Gene',
#    'symbol': 'MOGAT2',
#    'name': 'monoacylglycerol O-acyltransferase 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0019432',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'triglyceride biosynthetic process'}},
#  {'subject': {'id': 'GO:0000226',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'microtubule cytoskeleton organization'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:83887',
#    'type': 'biolink:Gene',
#    'symbol': 'TTLL2',
#    'name': 'tubulin tyrosine ligase like 2'}},
#  {'subject': {'id': 'NCBIGene:54549',
#    'type': 'biolink:Gene',
#    'symbol': 'SDK2',
#    'name': 'sidekick cell adhesion molecule 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0007156',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'homophilic cell adhesion via plasma membrane adhesion molecules'}},
#  {'subject': {'id': 'NCBIGene:1244',
#    'type': 'biolink:Gene',
#    'symbol': 'ABCC2',
#    'name': 'ATP binding cassette subfamily C member 2'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-5619115',
#    'type': 'biolink:Pathway',
#    'name': 'Disorders of transmembrane transporters'}},
#  {'subject': {'id': 'NCBIGene:1859',
#    'type': 'biolink:Gene',
#    'symbol': 'DYRK1A',
#    'name': 'dual specificity tyrosine phosphorylation regulated kinase 1A'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0007623',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'circadian rhythm'}},
#  {'subject': {'id': 'NCBIGene:4583',
#    'type': 'biolink:Gene',
#    'symbol': 'MUC2',
#    'name': 'mucin 2, oligomeric mucus/gel-forming'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0048874',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'host-mediated regulation of intestinal microbiota composition'}},
#  {'subject': {'id': 'NCBIGene:54806',
#    'type': 'biolink:Gene',
#    'symbol': 'AHI1',
#    'name': 'Abelson helper integration site 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-5620912',
#    'type': 'biolink:Pathway',
#    'name': 'Anchoring of the basal body to the plasma membrane'}},
#  {'subject': {'id': 'NCBIGene:8403',
#    'type': 'biolink:Gene',
#    'symbol': 'SOX14',
#    'name': 'SRY-box transcription factor 14'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0007420',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'brain development'}},
#  {'subject': {'id': 'NCBIGene:5700',
#    'type': 'biolink:Gene',
#    'symbol': 'PSMC1',
#    'name': 'proteasome 26S subunit, ATPase 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-212436',
#    'type': 'biolink:Pathway',
#    'name': 'Generic Transcription Pathway'}},
#  {'subject': {'id': 'GO:0006508',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'proteolysis'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:28972',
#    'type': 'biolink:Gene',
#    'symbol': 'SPCS1',
#    'name': 'signal peptidase complex subunit 1'}},
#  {'subject': {'id': 'NCBIGene:6202',
#    'type': 'biolink:Gene',
#    'symbol': 'RPS8',
#    'name': 'ribosomal protein S8'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-72766',
#    'type': 'biolink:Pathway',
#    'name': 'Translation'}},
#  {'subject': {'id': 'NCBIGene:111',
#    'type': 'biolink:Gene',
#    'symbol': 'ADCY5',
#    'name': 'adenylate cyclase 5'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-111931',
#    'type': 'biolink:Pathway',
#    'name': 'PKA-mediated phosphorylation of CREB'}},
#  {'subject': {'id': 'NCBIGene:10498',
#    'type': 'biolink:Gene',
#    'symbol': 'CARM1',
#    'name': 'coactivator associated arginine methyltransferase 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-2151201',
#    'type': 'biolink:Pathway',
#    'name': 'Transcriptional activation of mitochondrial biogenesis'}},
#  {'subject': {'id': 'GO:0007165',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'signal transduction'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:22821',
#    'type': 'biolink:Gene',
#    'symbol': 'RASA3',
#    'name': 'RAS p21 protein activator 3'}},
#  {'subject': {'id': 'GO:0031175',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'TAS',
#    'term': 'neuron projection development'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:51560',
#    'type': 'biolink:Gene',
#    'symbol': 'RAB6B',
#    'name': 'RAB6B, member RAS oncogene family'}},
#  {'subject': {'id': 'GO:0007219',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'Notch signaling pathway'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:4854',
#    'type': 'biolink:Gene',
#    'symbol': 'NOTCH3',
#    'name': 'notch receptor 3'}},
#  {'subject': {'id': 'GO:0034504',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'protein localization to nucleus'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:5356',
#    'type': 'biolink:Gene',
#    'symbol': 'PLRG1',
#    'name': 'pleiotropic regulator 1'}},
#  {'subject': {'id': 'NCBIGene:6628',
#    'type': 'biolink:Gene',
#    'symbol': 'SNRPB',
#    'name': 'small nuclear ribonucleoprotein polypeptides B and B1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-73856',
#    'type': 'biolink:Pathway',
#    'name': 'RNA Polymerase II Transcription Termination'}},
#  {'subject': {'id': 'NCBIGene:5243',
#    'type': 'biolink:Gene',
#    'symbol': 'ABCB1',
#    'name': 'ATP binding cassette subfamily B member 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:1990962',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'xenobiotic transport across blood-brain barrier'}},
#  {'subject': {'id': 'NCBIGene:996',
#    'type': 'biolink:Gene',
#    'symbol': 'CDC27',
#    'name': 'cell division cycle 27'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-68867',
#    'type': 'biolink:Pathway',
#    'name': 'Assembly of the pre-replicative complex'}},
#  {'subject': {'id': 'GO:0016055',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'Wnt signaling pathway'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:5310',
#    'type': 'biolink:Gene',
#    'symbol': 'PKD1',
#    'name': 'polycystin 1, transient receptor potential channel interacting'}},
#  {'subject': {'id': 'GO:0051793',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IBA',
#    'term': 'medium-chain fatty acid catabolic process'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:34',
#    'type': 'biolink:Gene',
#    'symbol': 'ACADM',
#    'name': 'acyl-CoA dehydrogenase medium chain'}},
#  {'subject': {'id': 'NCBIGene:8818',
#    'type': 'biolink:Gene',
#    'symbol': 'DPM2',
#    'name': 'dolichyl-phosphate mannosyltransferase subunit 2, regulatory'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0031647',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IPI',
#    'term': 'regulation of protein stability'}},
#  {'subject': {'id': 'NCBIGene:55667',
#    'type': 'biolink:Gene',
#    'symbol': 'DENND4C',
#    'name': 'DENN domain containing 4C'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0072659',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'ISS',
#    'term': 'protein localization to plasma membrane'}},
#  {'subject': {'id': 'NCBIGene:55746',
#    'type': 'biolink:Gene',
#    'symbol': 'NUP133',
#    'name': 'nucleoporin 133'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-4085377',
#    'type': 'biolink:Pathway',
#    'name': 'SUMOylation of SUMOylation proteins'}},
#  {'subject': {'id': 'NCBIGene:776',
#    'type': 'biolink:Gene',
#    'symbol': 'CACNA1D',
#    'name': 'calcium voltage-gated channel subunit alpha1 D'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-400042',
#    'type': 'biolink:Pathway',
#    'name': 'Adrenaline,noradrenaline inhibits insulin secretion'}},
#  {'subject': {'id': 'NCBIGene:84172',
#    'type': 'biolink:Gene',
#    'symbol': 'POLR1B',
#    'name': 'RNA polymerase I subunit B'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-5250924',
#    'type': 'biolink:Pathway',
#    'name': 'B-WICH complex positively regulates rRNA expression'}},
#  {'subject': {'id': 'GO:0010574',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'regulation of vascular endothelial growth factor production'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:57447',
#    'type': 'biolink:Gene',
#    'symbol': 'NDRG2',
#    'name': 'NDRG family member 2'}},
#  {'subject': {'id': 'NCBIGene:844',
#    'type': 'biolink:Gene',
#    'symbol': 'CASQ1',
#    'name': 'calsequestrin 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:2001256',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IMP',
#    'term': 'regulation of store-operated calcium entry'}},
#  {'subject': {'id': 'GO:0007616',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IGI',
#    'term': 'long-term memory'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:348',
#    'type': 'biolink:Gene',
#    'symbol': 'APOE',
#    'name': 'apolipoprotein E'}},
#  {'subject': {'id': 'NCBIGene:64834',
#    'type': 'biolink:Gene',
#    'symbol': 'ELOVL1',
#    'name': 'ELOVL fatty acid elongase 1'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-2046104',
#    'type': 'biolink:Pathway',
#    'name': 'alpha-linolenic (omega3) and linoleic (omega6) acid metabolism'}},
#  {'subject': {'id': 'NCBIGene:2068',
#    'type': 'biolink:Gene',
#    'symbol': 'ERCC2',
#    'name': 'ERCC excision repair 2, TFIIH core complex helicase subunit'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'GO:0032289',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'central nervous system myelin formation'}},
#  {'subject': {'id': 'GO:0034644',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'cellular response to UV'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:94241',
#    'type': 'biolink:Gene',
#    'symbol': 'TP53INP1',
#    'name': 'tumor protein p53 inducible nuclear protein 1'}},
#  {'subject': {'id': 'GO:0042742',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'defense response to bacterium'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:23118',
#    'type': 'biolink:Gene',
#    'symbol': 'TAB2',
#    'name': 'TGF-beta activated kinase 1 (MAP3K7) binding protein 2'}},
#  {'subject': {'id': 'GO:0009408',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IDA',
#    'term': 'response to heat'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:49860',
#    'type': 'biolink:Gene',
#    'symbol': 'CRNN',
#    'name': 'cornulin'}},
#  {'subject': {'id': 'NCBIGene:79751',
#    'type': 'biolink:Gene',
#    'symbol': 'SLC25A22',
#    'name': 'solute carrier family 25 member 22'},
#   'predicate': {'type': 'biolink:participates_in'},
#   'object': {'id': 'R-HSA-1430728',
#    'type': 'biolink:Pathway',
#    'name': 'Metabolism'}},
#  {'subject': {'id': 'GO:0098880',
#    'type': 'biolink:BiologicalProcess',
#    'evidence': 'IEA',
#    'term': 'maintenance of postsynaptic specialization structure'},
#   'predicate': {'type': 'biolink:has_participant'},
#   'object': {'id': 'NCBIGene:3690',
#    'type': 'biolink:Gene',
#    'symbol': 'ITGB3',
#    'name': 'integrin subunit beta 3'}}]
